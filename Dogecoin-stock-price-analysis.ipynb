# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#read the csv file into the Dataframe
df=pd.read_csv("DOGE-USD.csv")

#list of first five rows
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close   Volume
# 0  2017-11-09  0.001207  0.001415  0.001181  0.001415   0.001415  6259550
# 1  2017-11-10  0.001421  0.001431  0.001125  0.001163   0.001163  4246520
# 2  2017-11-11  0.001146  0.001257  0.001141  0.001201   0.001201  2231080
# 3  2017-11-12  0.001189  0.001210  0.001002  0.001038   0.001038  3288960
# 4  2017-11-13  0.001046  0.001212  0.001019  0.001211   0.001211  2481270

# %%
#list of last five rows
df.tail()
# Out:
#             Date      Open      High       Low     Close  Adj Close     Volume
# 2159  2023-10-08  0.061456  0.061611  0.060876  0.061008   0.061008   92483679
# 2160  2023-10-09  0.061010  0.061030  0.058260  0.058779   0.058779  241183528
# 2161  2023-10-10  0.058779  0.059204  0.058608  0.059025   0.059025  123311323
# 2162  2023-10-11  0.059041  0.059454  0.057813  0.058470   0.058470  146066511
# 2163  2023-10-12  0.058470  0.058488  0.057500  0.057771   0.057771  120287472

# %%
#shape
df.shape
# Out:
# (2164, 7)

# %% [markdown]
# **INFERENCE**

# %% [markdown]
# **The Dataset comprises of 2164 rows and 7 columns.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2164 entries, 0 to 2163
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2164 non-null   object
#  1   Open       2164 non-null   float64
#  2   High       2164 non-null   float64
#  3   Low        2164 non-null   float64
#  4   Close      2164 non-null   float64
#  5   Adj Close  2164 non-null   float64
#  6   Volume     2164 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 118.5+ KB

# %% [markdown]
# **INFERENCE**

# %% [markdown]
# **No variable column as null/missing values.**

# %%
#Name of all the columns
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2164.000000  2164.000000  2164.000000  2164.000000  2164.000000
# mean      0.062426     0.065708     0.059261     0.062462     0.062462
# std       0.091750     0.098803     0.084913     0.091797     0.091797
# min       0.001046     0.001210     0.001002     0.001038     0.001038
# 25%       0.002656     0.002722     0.002597     0.002657     0.002657
# 50%       0.005992     0.006431     0.005719     0.006014     0.006014
# 75%       0.080191     0.082483     0.077584     0.080190     0.080190
# max       0.687801     0.737567     0.608168     0.684777     0.684777
#
#              Volume
# count  2.164000e+03
# mean   9.358082e+08
# std    3.246002e+09
# min    1.431720e+06
# 25%    3.645901e+07
# 50%    1.645669e+08
# 75%    6.216320e+08
# max    6.941068e+10

# %%
#unique items in the dataset
df.nunique()
# Out:
# Date         2164
# Open         1933
# High         1938
# Low          1924
# Close        1941
# Adj Close    1941
# Volume       2164
# dtype: int64

# %%
#check for missing values

df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Set 'Date' as the index for time-based plotting
df.set_index('Date', inplace=True)

# Time Series Plot - Dogecoin Prices Over Time
plt.figure(figsize=(12, 6))
plt.plot(df['Close'], label='Closing Price', color='blue')
plt.title('Dogecoin Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.show()

# %% [markdown]
# **INFERENCE**

# %% [markdown]
# **1. Overall Trend: The plot reveals the overall trend in Dogecoin prices, showcasing periods of upward and downward movements.Understanding these trends is essential for investors and analysts seeking to make informed decisions.**

# %% [markdown]
# **2. Volatility Analysis: Fluctuations in the line reveal the volatility in Dogecoin prices. Sharp spikes or drops may indicate periods of increased market activity, speculative interest, or external factors influencing the cryptocurrency market.**

# %% [markdown]
# **3. Pattern Recognition: Repeated patterns or cycles in the plot may suggest recurring market behaviors. Identifying such patterns can aid in anticipating potential future price movements.**

# %%
# Histogram - Distribution of Closing Prices
plt.figure(figsize=(10, 6))
sns.histplot(df['Close'], bins=30, color='purple')
plt.title('Distribution of Dogecoin Closing Prices')
plt.xlabel('Closing Price (USD)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **INFERENCE**

# %% [markdown]
# **1. Dominant Price Ranges: The histogram reveals the most frequent closing price ranges that is 0.0, indicating where the market tends to concentrate.**

# %% [markdown]
# **2. Bimodal or Multimodal Patterns: The presence of multiple peaks in the histogram from 0.1 to 0.3 suggests distinct market regimes or phases with different dominant price levels.**

# %%
# Moving Averages
df['Close_MA_20'] = df['Close'].rolling(window=20).mean()

plt.figure(figsize=(12, 6))
plt.plot(df['Close'], label='Closing Price', color='blue')
plt.plot(df['Close_MA_20'], label='20-Day Moving Average', color='red')
plt.title('Dogecoin Prices with 20-Day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.show()

# %% [markdown]
# **INFERENCE**

# %% [markdown]
# **1. In the plotted chart, the blue line represents the daily closing prices of Dogecoin, providing a clear view of the price fluctuations over time. The red line represents the 20-day moving average, which is a smoothed trend line calculated by taking the average of the closing prices over a 20-day period.**

# %% [markdown]
# **2. The moving average serves as a valuable indicator to identify trends, filter out short-term fluctuations, and highlight the underlying price direction**
